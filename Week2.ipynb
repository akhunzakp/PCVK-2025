# %% [markdown]
# <a href="https://colab.research.google.com/github/akhunzakp/PCVK_2025/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODUL 2**
#
# Penggunaan Numpy dan OpenCV serta Pengenalan
# Aplikasi-aplikasi Pengolahan Citra

# %% [markdown]
# # **Praktikum 1**

# %% [markdown]
# Kemudian import folder yang ada di Drive Anda dengan cara sebagai berikut.

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Google Colab sudah dapat mengakses folder gdrive Anda dengan
# keterangan output program “Mounted at /content/drive”.

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada. Contohnya pada kode program di bawah file image dengan nama
# kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img)
#perhatikan hasilnya adalah citra dgn channel warna BGR

# %% [markdown]
# Hasil nya berupa output gambar yang sudah di plot dengan matplotlib untuk
# mengetahui ukuran panjang dan lebar dari gambar tersebut.

# %% [markdown]
# # **Praktikum 2**

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# # **Praktikum 3**

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
# citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# # **Praktikum 4**

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512, 512,3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0), pt2 = (510, 150) ,color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200), pt2 = (300, 300) ,color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100), radius=50 ,color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img,pt1=(0,0), pt2=(512,512) ,color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv. FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(18,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2, [pts], isClosed=True,color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **Praktikum 5**

# %% [markdown]
# Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih
# File kemudian “Save a copy in GitHub”.

# %% [markdown]
# # **Tugas**
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow   # kalau di Google Colab

# --- Membaca gambar kitten01 ---
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten02.jpg')   # pastikan file kitten01.jpg ada di folder kerja
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # ubah ke RGB untuk matplotlib

# 1. Ukuran image dengan figsize (tidak mengubah pixel image, hanya tampilan plot)
plt.figure(figsize=(12,6))
plt.imshow(img_rgb)
print("Ukuran asli gambar (pixel):", img.shape)   # (height, width, channel)
# Out:
# Ukuran asli gambar (pixel): (215, 236, 3)

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Green

# %%
# Extract Red and Green channels
img_rg = img.copy()
img_rg[:, :, 2] = 0  # Set Blue channel to zero

# Display the Red-Green image
plt.imshow(img_rg)
plt.title('Red-Green Channels')
plt.show()

# %% [markdown]
# Tampilkan image dalam channel Green-Blue saja!

# %%
# Extract Green and Blue channels
img_gb = img.copy()
img_gb[:, :, 0] = 0  # Set Red channel to zero

# Display the Green-Blue image
plt.imshow(img_gb)
plt.title('Green-Blue Channels')
plt.show()

# %% [markdown]
# 3. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
# Slice the image
img_slice = img[10:101, 10:101, :]

# Display the sliced image
plt.imshow(img_slice)
plt.title('Image Slice (Rows 10-100, Cols 10-100)')
plt.show()

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
# Slice the image to get rows 5-30, all columns, and the Green channel
img_slice_green = img[5:31, :, 1]

# Display the sliced image (Green channel)
plt.imshow(img_slice_green, cmap='gray')
plt.title('Image Slice (Rows 5-30, All Cols, Green Channel)')
plt.show()

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
# 1. Create a black image
height, width = 512, 512
black_img = np.zeros(shape=(height, width, 3), dtype=np.uint8)

# 2. Use a loop to draw 5 rectangles
num_rectangles = 5
for _ in range(num_rectangles):
    # 3. Generate random coordinates
    x1, y1 = np.random.randint(0, width // 2), np.random.randint(0, height // 2)
    x2, y2 = np.random.randint(width // 2, width), np.random.randint(height // 2, height)

    # 4. Generate random color values
    color = (np.random.randint(0, 256), np.random.randint(0, 256), np.random.randint(0, 256))

    # 5. Draw each rectangle
    thickness = np.random.randint(1, 10)  # Random thickness
    cv.rectangle(black_img, pt1=(x1, y1), pt2=(x2, y2), color=color, thickness=thickness)

# 6. Display the resulting image
plt.imshow(black_img)
plt.title('Image with 5 Random Rectangles')
plt.show()

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(5,5))     #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
ax.imshow(img5)

print("Shape of img:", img.shape)
# Out:
# Shape of img: (215, 236, 3)

# %% [markdown]
# **Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :**
#
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/Images/kitten02.jpg')


face_img = img.copy()

# Rectangle
cv2.rectangle(face_img, (10, 10), (200, 190), (0, 0, 255), 3)

# Dua lingkaran
cv2.circle(face_img, (68, 55), 20, (0, 255, 0), 3)
cv2.circle(face_img, (145, 60), 20, (0, 255, 0), 3)

# Convert BGR ke RGB untuk ditampilkan dengan matplotlib
face_img_rgb = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)

# Tampilkan
plt.imshow(face_img_rgb)
plt.show()

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
B_channel = img[:,:,0]   # channel B (dari BGR asli)
h, w = B_channel.shape
B_copy = cv2.cvtColor(B_channel, cv2.COLOR_GRAY2BGR)
cv2.rectangle(B_copy, (0,h-50), (50,h), (255,0,0), 2)
plt.imshow(B_copy)
plt.show()

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.

# %%
B_text = B_copy.copy()
cv2.putText(B_text, "kitten01.jpg", (10,h-60),
            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,255), 2)
plt.imshow(B_text)
plt.show()

# %% [markdown]
# # **GROUP TASK 9 Golden and Putra**
#
# Group 9 closes the name of the province and district at the very top of the KTP.

# %%
# Baca gambar langsung

import cv2 as cv
import matplotlib.pyplot as plt
img = cv2.imread('/content/drive/MyDrive/PCVK/Images/KTP.png')

# Tutup tulisan "PROVINSI DKI JAKARTA"
prov_coords_pt1 = (150, 30)   # kiri atas
prov_coords_pt2 = (320, 50)   # kanan bawah
cv.rectangle(img, prov_coords_pt1, prov_coords_pt2,
             color=(0, 0, 0),)

# Tutup tulisan "JAKARTA BARAT"
dist_coords_pt1 = (180, 50)   # kiri atas
dist_coords_pt2 = (300, 70)   # kanan bawah
cv.rectangle(img, dist_coords_pt1, dist_coords_pt2,
             color=(0, 0, 0), )

# Tampilkan hasil
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
